# %% [markdown]
# #  **ICT303 - Assignment 2**
#
# **Your name: Lee Ming Han**
#
# **Student ID: 34307477**
#
# **Email: chah3929@gmail.com**
#
# In this assignment, you will build a deep learning model for identifying $120$ different breeds of dogs. Similar to the previous assignment, you will use real images from the [Kaggle competition](https://www.kaggle.com/c/dog-breed-identification).
#
# In this assignment, your are required to use a ResNet network. You can use ResNet implementation provided in PyTorch. Note however  that there are many versions of ResNet (they differ in terms of number of layers). Your task is to find the best configuration that gives the best performance.
#
# The rule is similar to the previous assignment:
#
# 1. Develop a better model to reduce the recognition error.
# 2. Submit your results to Kaggle and take a sceenshot of your score. Then insert here the screenshot of your result.
#
# It is important that you start as earlier as possible. Tuning hyper-parameters takes time, and Kaggle limits the number of submissions per day.
#
# The top 3 students in the Kaggle ranking will be invited for a coffee!

# %%
# Import required libraries
import numpy as np
import pandas as pd
import cv2
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model, Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.applications.resnet_v2 import ResNet50V2, preprocess_input

# %%
# Read the CSV file and store it in the 'labels_file' variable
labels_file = pd.read_csv("labels.csv")

# Store training and testing images folder location
train_file = 'train/'
test_file = 'test/'

# %%
# Check the total number of unique dog breeds in the dataset
print("Unique Dog Breeds:", len(labels_file.breed.unique()))
# Out:
# Unique Dog Breeds: 120

# %%
# Specify the number of dog breeds in the dataset
num_breeds = 120

# Specify the batch size used during model training
batch_size = 64

# Create an instance of the LabelEncoder to encode categorical labels into numeric values
label_encoder = LabelEncoder()

# %%
# Get the breed_dict with breed counts
breed_dict = labels_file['breed'].value_counts().to_dict()

# Get the list of 120 unique breeds with highest counts
new_list = sorted(breed_dict.keys(), key=lambda x: breed_dict[x], reverse=True)[:num_breeds]

# Change the dataset to have those 120 unique breed records
labels_file = labels_file.query('breed in @new_list')

# %%
# Create a new column 'img_file' containing the image names with the image extension
labels_file['img_file'] = labels_file['id'].apply(lambda x: x + ".jpg")

# %%
labels_file
# Out:
#                                      id                     breed  \
# 0      000bec180eb18c7604dcecc8fe0dba07               boston_bull
# 1      001513dfcb2ffafc82cccf4d8bbaba97                     dingo
# 2      001cdf01b096e06d78e9e5112d419397                  pekinese
# 3      00214f311d5d2247d5dfe4fe24b2303d                  bluetick
# 4      0021f9ceb3235effd7fcde7f7538ed62          golden_retriever
# ...                                 ...                       ...
# 10217  ffd25009d635cfd16e793503ac5edef0                    borzoi
# 10218  ffd3f636f7f379c51ba3648a9ff8254f            dandie_dinmont
# 10219  ffe2ca6c940cddfee68fa3cc6c63213f                  airedale
# 10220  ffe5f6d8e2bff356e9482a80a6e29aac        miniature_pinscher
# 10221  fff43b07992508bc822f33d8ffd902ae  chesapeake_bay_retriever
#
#                                    img_file
# 0      000bec180eb18c7604dcecc8fe0dba07.jpg
# 1      001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2      001cdf01b096e06d78e9e5112d419397.jpg
# 3      00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4      0021f9ceb3235effd7fcde7f7538ed62.jpg
# ...                                     ...
# 10217  ffd25009d635cfd16e793503ac5edef0.jpg
# 10218  ffd3f636f7f379c51ba3648a9ff8254f.jpg
# 10219  ffe2ca6c940cddfee68fa3cc6c63213f.jpg
# 10220  ffe5f6d8e2bff356e9482a80a6e29aac.jpg
# 10221  fff43b07992508bc822f33d8ffd902ae.jpg
#
# [10222 rows x 3 columns]

# %%
# Image size for resizing the images
image_size = 256

# Number of dataset records
num_records = len(labels_file)

# Initialize an array to store the preprocessed images
train_x = np.zeros((num_records, image_size, image_size, 3), dtype='float32')

# Iterate over the 'img_file' column of the DataFrame and preprocess the images
for i, img_id in enumerate(labels_file['img_file']):
    img = cv2.resize(cv2.imread('train/' + img_id, cv2.IMREAD_COLOR), (image_size, image_size))
    img_array = preprocess_input(np.expand_dims(np.array(img[..., ::-1].astype(np.float32)).copy(), axis=0))
    train_x[i] = img_array

# %%
# Initialize the LabelEncoder
encoder = LabelEncoder()

# Convert breed names into numerical format and store in 'train_y'
train_y = encoder.fit_transform(labels_file["breed"].values)

# %%
# Split the dataset into training and testing sets (80% training and 20% testing)
x_train, x_test, y_train, y_test = train_test_split(train_x, train_y, test_size=0.2, random_state=42)

# %%
# Image augmentation for the training set
train_datagen = ImageDataGenerator(rotation_range=45,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.25,
                                   horizontal_flip=True,
                                   fill_mode='nearest')

# Generate augmented images for training sets
train_data_generator = train_datagen.flow(x_train,
                                     y_train,
                                     batch_size=batch_size)

# Image augmentation for the testing set
test_datagen = ImageDataGenerator()

# Generate augmented images for testing sets
test_data_generator = test_datagen.flow(x_test,
                                   y_test,
                                   batch_size=batch_size)

# %%
# Specify the number of dog breeds in the dataset
num_breeds = 120

# Build the ResNet50V2 model with input shape and pre-trained weights
resnet = ResNet50V2(input_shape=[image_size, image_size, 3], weights='imagenet', include_top=False)

# Freeze all trainable layers and train only top layers
for layer in resnet.layers:
    layer.trainable = False

# Add Global Average Pooling and Batch Normalization layers
x = resnet.output
x = BatchNormalization()(x)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)

# Add a fully connected layer
x = Dense(1024, activation='relu')(x)
x = Dropout(0.5)(x)

# Add the output layer with the number of dog breeds as the number of neurons and softmax activation
predictions = Dense(num_breeds, activation='softmax')(x)

# Create the final model with inputs from ResNet50V2 and outputs from the new output layer
model = Model(inputs=resnet.input, outputs=predictions)

# %%
#epochs for model training and learning rate for optimizer
epochs = 30
learning_rate = 1e-3

# Specify the batch size used during model training
batch_size = 64

#using RMSprop optimizer to compile or build the model
optimizer = RMSprop(learning_rate=learning_rate,rho=0.9)
model.compile(optimizer=optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=["accuracy"])

#fit the training generator data and train the model
hist = model.fit(train_data_generator,
                 steps_per_epoch= x_train.shape[0] // batch_size,
                 epochs= epochs,
                 validation_data= test_data_generator,
                 validation_steps= x_test.shape[0] // batch_size)

#Save the model for prediction
model.save("model")
# Out:
# Epoch 1/30
# 127/127 [==============================] - 540s 4s/step - loss: 2.5931 - accuracy: 0.3869 - val_loss: 0.9292 - val_accuracy: 0.7303
# Epoch 2/30
# 127/127 [==============================] - 513s 4s/step - loss: 1.4613 - accuracy: 0.5847 - val_loss: 0.7735 - val_accuracy: 0.7651
# Epoch 3/30
# 127/127 [==============================] - 513s 4s/step - loss: 1.2899 - accuracy: 0.6279 - val_loss: 0.7452 - val_accuracy: 0.7692
# Epoch 4/30
# 127/127 [==============================] - 508s 4s/step - loss: 1.2214 - accuracy: 0.6513 - val_loss: 0.7486 - val_accuracy: 0.7681
# Epoch 5/30
# 127/127 [==============================] - 508s 4s/step - loss: 1.1571 - accuracy: 0.6672 - val_loss: 0.7535 - val_accuracy: 0.7747
# Epoch 6/30
# 127/127 [==============================] - 508s 4s/step - loss: 1.0939 - accuracy: 0.6798 - val_loss: 0.7627 - val_accuracy: 0.7792
# Epoch 7/30
# 127/127 [==============================] - 507s 4s/step - loss: 1.0677 - accuracy: 0.6874 - val_loss: 0.7745 - val_accuracy: 0.7767
# Epoch 8/30
# 127/127 [==============================] - 507s 4s/step - loss: 1.0559 - accuracy: 0.6970 - val_loss: 0.7603 - val_accuracy: 0.7823
# Epoch 9/30
# 127/127 [==============================] - 511s 4s/step - loss: 1.0077 - accuracy: 0.7100 - val_loss: 0.7499 - val_accuracy: 0.7787
# Epoch 10/30
# 127/127 [==============================] - 506s 4s/step - loss: 0.9870 - accuracy: 0.7163 - val_loss: 0.7505 - val_accuracy: 0.7802
# Epoch 11/30
# 127/127 [==============================] - 507s 4s/step - loss: 0.9816 - accuracy: 0.7168 - val_loss: 0.7613 - val_accuracy: 0.7772
# Epoch 12/30
# 127/127 [==============================] - 509s 4s/step - loss: 0.9684 - accuracy: 0.7229 - val_loss: 0.7750 - val_accuracy: 0.7818
# Epoch 13/30
# 127/127 [==============================] - 506s 4s/step - loss: 0.9511 - accuracy: 0.7264 - val_loss: 0.7802 - val_accuracy: 0.7747
# Epoch 14/30
# 127/127 [==============================] - 509s 4s/step - loss: 0.9420 - accuracy: 0.7269 - val_loss: 0.7846 - val_accuracy: 0.7818
# Epoch 15/30
# 127/127 [==============================] - 507s 4s/step - loss: 0.9087 - accuracy: 0.7357 - val_loss: 0.8378 - val_accuracy: 0.7681
# Epoch 16/30
# 127/127 [==============================] - 509s 4s/step - loss: 0.8952 - accuracy: 0.7381 - val_loss: 0.8198 - val_accuracy: 0.7732
# Epoch 17/30
# 127/127 [==============================] - 505s 4s/step - loss: 0.9015 - accuracy: 0.7384 - val_loss: 0.8348 - val_accuracy: 0.7762
# Epoch 18/30
# 127/127 [==============================] - 506s 4s/step - loss: 0.8888 - accuracy: 0.7428 - val_loss: 0.8242 - val_accuracy: 0.7752
# Epoch 19/30
# 127/127 [==============================] - 510s 4s/step - loss: 0.8986 - accuracy: 0.7429 - val_loss: 0.8300 - val_accuracy: 0.7767
# Epoch 20/30
# 127/127 [==============================] - 509s 4s/step - loss: 0.8650 - accuracy: 0.7481 - val_loss: 0.8125 - val_accuracy: 0.7818
# Epoch 21/30
# 127/127 [==============================] - 505s 4s/step - loss: 0.8772 - accuracy: 0.7469 - val_loss: 0.8235 - val_accuracy: 0.7752
# Epoch 22/30
# 127/127 [==============================] - 506s 4s/step - loss: 0.8686 - accuracy: 0.7497 - val_loss: 0.8565 - val_accuracy: 0.7843
# Epoch 23/30
# 127/127 [==============================] - 508s 4s/step - loss: 0.8701 - accuracy: 0.7506 - val_loss: 0.8647 - val_accuracy: 0.7717
# Epoch 24/30
# 127/127 [==============================] - 505s 4s/step - loss: 0.8347 - accuracy: 0.7584 - val_loss: 0.8895 - val_accuracy: 0.7697
# Epoch 25/30
# 127/127 [==============================] - 505s 4s/step - loss: 0.8614 - accuracy: 0.7495 - val_loss: 0.8836 - val_accuracy: 0.7697
# Epoch 26/30
# 127/127 [==============================] - 510s 4s/step - loss: 0.8317 - accuracy: 0.7589 - val_loss: 0.8972 - val_accuracy: 0.7692
# Epoch 27/30
# 127/127 [==============================] - 512s 4s/step - loss: 0.8659 - accuracy: 0.7504 - val_loss: 0.8815 - val_accuracy: 0.7772
# Epoch 28/30
# 127/127 [==============================] - 537s 4s/step - loss: 0.8193 - accuracy: 0.7662 - val_loss: 0.9051 - val_accuracy: 0.7717
# Epoch 29/30
# 127/127 [==============================] - 581s 5s/step - loss: 0.8434 - accuracy: 0.7642 - val_loss: 0.8907 - val_accuracy: 0.7772
# Epoch 30/30
# 127/127 [==============================] - 577s 5s/step - loss: 0.8123 - accuracy: 0.7657 - val_loss: 0.8913 - val_accuracy: 0.7807
# INFO:tensorflow:Assets written to: model\assets
# INFO:tensorflow:Assets written to: model\assets

# %%
# Output the result to a csv file

import os

# Specify the batch size used during model training
batch_size = 64

# Assuming you have already loaded and trained the model
# and have the predictions in 'labels_file' DataFrame
model = load_model("model")

# Define the image size (assuming im_size is defined)
image_size = 256

# Path to the folder containing the test images
test_folder_path = 'test/'

# List to store predictions and corresponding image ids
predictions = []
image_ids = []

# List of unique breed names (assuming new_list is defined)
unique_breeds = sorted(new_list)

# Loop through the test images
for filename in os.listdir(test_folder_path):
    if filename.endswith(".jpg"):
        image_path = os.path.join(test_folder_path, filename)

        # Read and preprocess the image
        img_array = cv2.resize(cv2.imread(image_path, cv2.IMREAD_COLOR), (image_size, image_size))
        img_array = preprocess_input(np.expand_dims(np.array(img_array[..., ::-1].astype(np.float32)).copy(), axis=0))

        # Feed the model with the image array for prediction
        pred_val = model.predict(np.array(img_array, dtype="float32"))

        # Append the prediction probabilities to the predictions list
        predictions.append(pred_val[0])

        # Extract the image ID without the file extension
        image_id = os.path.splitext(filename)[0]
        image_ids.append(image_id)

# Create a DataFrame with the results
results_df = pd.DataFrame(predictions, columns=unique_breeds)
results_df.insert(0, 'id', image_ids)

# Set option to print the entire DataFrame with full precision
pd.set_option('display.float_format', lambda x: '%.10f' % x)

# Save the DataFrame to a CSV file
results_df.to_csv('submission.csv', index=False)
# Out:
# 1/1 [==============================] - 1s 919ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 130ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 155ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 215ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 153ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 139ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 132ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 133ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 124ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 134ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 123ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 135ms/step
# 1/1 [==============================] - 0s 128ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 116ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 118ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 137ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 101ms/step
# ...
# 1/1 [==============================] - 1s 656ms/step
# 1/1 [==============================] - 1s 718ms/step
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 1s 774ms/step
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 1s 784ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 731ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 658ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 675ms/step
# 1/1 [==============================] - 1s 666ms/step
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 1s 788ms/step
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 693ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 659ms/step
# 1/1 [==============================] - 1s 697ms/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 697ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 656ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 674ms/step
# 1/1 [==============================] - 1s 665ms/step
# 1/1 [==============================] - 1s 696ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 797ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 729ms/step
# 1/1 [==============================] - 1s 715ms/step
# 1/1 [==============================] - 1s 717ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 677ms/step
# 1/1 [==============================] - 1s 662ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 663ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 665ms/step
# 1/1 [==============================] - 1s 697ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 793ms/step
# 1/1 [==============================] - 1s 808ms/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 683ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 693ms/step
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 1s 668ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 666ms/step
# 1/1 [==============================] - 1s 693ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 799ms/step
# 1/1 [==============================] - 1s 779ms/step
# 1/1 [==============================] - 1s 732ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 677ms/step
# 1/1 [==============================] - 1s 704ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 680ms/step
# 1/1 [==============================] - 1s 703ms/step
# 1/1 [==============================] - 1s 702ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 667ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 701ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 671ms/step
# 1/1 [==============================] - 1s 744ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 811ms/step
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 708ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 1s 678ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 709ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 693ms/step
# 1/1 [==============================] - 1s 704ms/step
# 1/1 [==============================] - 1s 791ms/step
# 1/1 [==============================] - 1s 834ms/step
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 1s 755ms/step
# 1/1 [==============================] - 1s 737ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 1s 751ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 758ms/step
# 1/1 [==============================] - 1s 709ms/step
# 1/1 [==============================] - 1s 702ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 716ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 776ms/step
# 1/1 [==============================] - 1s 801ms/step
# 1/1 [==============================] - 1s 803ms/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 698ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 693ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 711ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 1s 677ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 694ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 703ms/step
# 1/1 [==============================] - 1s 707ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 674ms/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 1s 832ms/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 1s 690ms/step
# 1/1 [==============================] - 1s 683ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 696ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 1s 702ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 704ms/step
# 1/1 [==============================] - 1s 747ms/step
# 1/1 [==============================] - 1s 794ms/step
# 1/1 [==============================] - 1s 800ms/step
# 1/1 [==============================] - 1s 738ms/step
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 1s 692ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 716ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 678ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 1s 691ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 708ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 719ms/step
# 1/1 [==============================] - 1s 697ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 764ms/step
# 1/1 [==============================] - 1s 836ms/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 752ms/step
# 1/1 [==============================] - 1s 679ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 721ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 775ms/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 725ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 715ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 1s 731ms/step
# 1/1 [==============================] - 1s 802ms/step
# 1/1 [==============================] - 1s 831ms/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 1s 710ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 689ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 708ms/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 703ms/step
# 1/1 [==============================] - 1s 717ms/step
# 1/1 [==============================] - 1s 703ms/step
# 1/1 [==============================] - 1s 687ms/step
# 1/1 [==============================] - 1s 716ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 697ms/step
# 1/1 [==============================] - 1s 681ms/step
# 1/1 [==============================] - 1s 711ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 676ms/step
# 1/1 [==============================] - 1s 714ms/step
# 1/1 [==============================] - 1s 842ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 1s 685ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 725ms/step
# 1/1 [==============================] - 1s 711ms/step
# 1/1 [==============================] - 1s 788ms/step
# 1/1 [==============================] - 1s 711ms/step
# 1/1 [==============================] - 1s 727ms/step
# 1/1 [==============================] - 1s 724ms/step
# 1/1 [==============================] - 1s 699ms/step
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 1s 718ms/step
# 1/1 [==============================] - 1s 708ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 706ms/step
# 1/1 [==============================] - 1s 730ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 683ms/step
# 1/1 [==============================] - 1s 798ms/step
# 1/1 [==============================] - 1s 847ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 712ms/step
# 1/1 [==============================] - 1s 686ms/step
# 1/1 [==============================] - 1s 723ms/step
# 1/1 [==============================] - 1s 725ms/step
# 1/1 [==============================] - 1s 708ms/step
# 1/1 [==============================] - 1s 688ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 733ms/step
# 1/1 [==============================] - 1s 721ms/step
# 1/1 [==============================] - 1s 720ms/step
# 1/1 [==============================] - 1s 704ms/step
# 1/1 [==============================] - 1s 696ms/step
# 1/1 [==============================] - 1s 724ms/step
# 1/1 [==============================] - 1s 722ms/step
# 1/1 [==============================] - 1s 682ms/step
# 1/1 [==============================] - 1s 704ms/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 837ms/step
# 1/1 [==============================] - 1s 815ms/step
# 1/1 [==============================] - 1s 703ms/step

# %% [markdown]
# ######

# %%
# Kaggle result is 0.7902

import matplotlib.pyplot as plt

image_path = 'Kaggle-result.png'

# Read the image file using OpenCV
image = cv2.imread(image_path)

# Check if the image was successfully read
if image is not None:
    
    # Convert BGR to RGB format
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Display the image using matplotlib
    plt.imshow(image_rgb)
    plt.axis('off')  # Hide the axis ticks and labels
    plt.show()
else:
    print("Failed to read the image.")

# %% [markdown]
# Hi sir, I apologize for the late submission. Actually, I had completed the assignment three days before the deadline, but I accidentally reran everything, which caused the previous output to disappear. In order to display all the output on the console, I had no choice but to wait for the whole model to run again. I am using a pretty old laptop to run everything on my CPU, as Google Colab kept crashing, which caused me to spend around three days to output all the results again. I am truly sorry, sir. I hope you won't penalize me for the late submission. Thank you.
